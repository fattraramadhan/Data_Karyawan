# %%
dict_karyawan_1={'first_name': 'putri', 'last_name': 'ayu', 'NIK': '111', 'alamat': 'palagan km1', 'tempat_tanggal_lahir': 'palagan_1_1_1', 'jenis_kelamin': 'wanita', 'agama': 'islam', 'hobi': 'masak', 'umur': '22', 'asal_universitas' : 'uty'}
print("dict_karyawan_1['first_name']:",dict_karyawan_1['first_name'])
print("dict_karyawan_1['last_name']:",dict_karyawan_1['last_name'])
print("dict_karyawan_1['NIK']:",dict_karyawan_1['NIK'])
print("dict_karyawan_1['alamat']:",dict_karyawan_1['alamat'])
print("dict_karyawan_1['tempat_tanggal_lahir']:",dict_karyawan_1['tempat_tanggal_lahir'])
print("dict_karyawan_1['jenis_kelamin']:",dict_karyawan_1['jenis_kelamin'])
print("dict_karyawan_1['agama']:",dict_karyawan_1['agama'])
print("dict_karyawan_1['hobi']:",dict_karyawan_1['hobi'])
print("dict_karyawan_1['umur']:",dict_karyawan_1['umur'])
print("dict_karyawan_1['asal_universitas']:",dict_karyawan_1['asal_universitas'])

dict_karyawan_2={'first_name': 'bagus', 'last_name': 'nugraha', 'NIK': '222', 'alamat': 'palagan km2', 'tempat_tanggal_lahir': 'palagan_2_2_2', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'ngegame', 'umur': '22', 'asal_universitas' : 'uny'}
print("dict_karyawan_2['first_name']:",dict_karyawan_2['first_name'])
print("dict_karyawan_2['last_name']:",dict_karyawan_2['last_name'])
print("dict_karyawan_2['NIK']:",dict_karyawan_2['NIK'])
print("dict_karyawan_2['alamat']:",dict_karyawan_2['alamat'])
print("dict_karyawan_2['tempat_tanggal_lahir']:",dict_karyawan_2['tempat_tanggal_lahir'])
print("dict_karyawan_2['jenis_kelamin']:",dict_karyawan_2['jenis_kelamin'])
print("dict_karyawan_2['agama']:",dict_karyawan_2['agama'])
print("dict_karyawan_2['hobi']:",dict_karyawan_2['hobi'])
print("dict_karyawan_2['umur']:",dict_karyawan_2['umur'])
print("dict_karyawan_2['asal_universitas']:",dict_karyawan_2['asal_universitas'])

dict_karyawan_3={'first_name': 'bagas', 'last_name': 'cahyo', 'NIK': '333', 'alamat': 'palagan km3', 'tempat_tanggal_lahir': 'palagan_3_3_3', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'mancing', 'umur': '22', 'asal_universitas' : 'ugm'}
print("dict_karyawan_3['first_name']:",dict_karyawan_3['first_name'])
print("dict_karyawan_3['last_name']:",dict_karyawan_3['last_name'])
print("dict_karyawan_3['NIK']:",dict_karyawan_3['NIK'])
print("dict_karyawan_3['alamat']:",dict_karyawan_3['alamat'])
print("dict_karyawan_3['tempat_tanggal_lahir']:",dict_karyawan_3['tempat_tanggal_lahir'])
print("dict_karyawan_3['jenis_kelamin']:",dict_karyawan_3['jenis_kelamin'])
print("dict_karyawan_3['agama']:",dict_karyawan_3['agama'])
print("dict_karyawan_3['hobi']:",dict_karyawan_3['hobi'])
print("dict_karyawan_3['umur']:",dict_karyawan_3['umur'])
print("dict_karyawan_3['asal_universitas']:",dict_karyawan_3['asal_universitas'])

dict_karyawan_4={'first_name': 'bayu', 'last_name': 'aji', 'NIK': '444', 'alamat': 'palagan km4', 'tempat_tanggal_lahir': 'palagan_4_4_4', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'sepak_bola', 'umur': '22', 'asal_universitas' : 'uty'}
print("dict_karyawan_4['first_name']:",dict_karyawan_4['first_name'])
print("dict_karyawan_4['last_name']:",dict_karyawan_4['last_name'])
print("dict_karyawan_4['NIK']:",dict_karyawan_4['NIK'])
print("dict_karyawan_4['alamat']:",dict_karyawan_4['alamat'])
print("dict_karyawan_4['tempat_tanggal_lahir']:",dict_karyawan_4['tempat_tanggal_lahir'])
print("dict_karyawan_4['jenis_kelamin']:",dict_karyawan_4['jenis_kelamin'])
print("dict_karyawan_4['agama']:",dict_karyawan_4['agama'])
print("dict_karyawan_4['hobi']:",dict_karyawan_4['hobi'])
print("dict_karyawan_4['umur']:",dict_karyawan_4['umur'])
print("dict_karyawan_4['asal_universitas']:",dict_karyawan_4['asal_universitas'])

dict_karyawan_5={'first_name': 'naufal', 'last_name': 'anshor', 'NIK': '555', 'alamat': 'palagan km5', 'tempat_tanggal_lahir': 'palagan_5_5_5', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'manicng', 'umur': '22', 'asal_universitas' : 'uny'}
print("dict_karyawan_5['first_name']:",dict_karyawan_5['first_name'])
print("dict_karyawan_5['last_name']:",dict_karyawan_5['last_name'])
print("dict_karyawan_5['NIK']:",dict_karyawan_5['NIK'])
print("dict_karyawan_5['alamat']:",dict_karyawan_5['alamat'])
print("dict_karyawan_5['tempat_tanggal_lahir']:",dict_karyawan_5['tempat_tanggal_lahir'])
print("dict_karyawan_5['jenis_kelamin']:",dict_karyawan_5['jenis_kelamin'])
print("dict_karyawan_5['agama']:",dict_karyawan_5['agama'])
print("dict_karyawan_5['hobi']:",dict_karyawan_5['hobi'])
print("dict_karyawan_5['umur']:",dict_karyawan_5['umur'])
print("dict_karyawan_5['asal_universitas']:",dict_karyawan_5['asal_universitas'])

dict_karyawan_6={'first_name': 'arif', 'last_name': 'candra', 'NIK': '666', 'alamat': 'palagan km6', 'tempat_tanggal_lahir': 'palagan_6_6_6', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'voly', 'umur': '22', 'asal_universitas' : 'ugm'}
print("dict_karyawan_6['first_name']:",dict_karyawan_6['first_name'])
print("dict_karyawan_6['last_name']:",dict_karyawan_6['last_name'])
print("dict_karyawan_6['NIK']:",dict_karyawan_6['NIK'])
print("dict_karyawan_6['alamat']:",dict_karyawan_6['alamat'])
print("dict_karyawan_6['tempat_tanggal_lahir']:",dict_karyawan_6['tempat_tanggal_lahir'])
print("dict_karyawan_6['jenis_kelamin']:",dict_karyawan_6['jenis_kelamin'])
print("dict_karyawan_6['agama']:",dict_karyawan_6['agama'])
print("dict_karyawan_6['hobi']:",dict_karyawan_6['hobi'])
print("dict_karyawan_6['umur']:",dict_karyawan_6['umur'])
print("dict_karyawan_6['asal_universitas']:",dict_karyawan_6['asal_universitas'])

dict_karyawan_7={'first_name': 'risky', 'last_name': 'ramadhan', 'NIK': '777', 'alamat': 'palagan km7', 'tempat_tanggal_lahir': 'palagan_7_7_7', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'basket', 'umur': '22', 'asal_universitas' : 'uty'}
print("dict_karyawan_7['first_name']:",dict_karyawan_7['first_name'])
print("dict_karyawan_7['last_name']:",dict_karyawan_7['last_name'])
print("dict_karyawan_7['NIK']:",dict_karyawan_7['NIK'])
print("dict_karyawan_7['alamat']:",dict_karyawan_7['alamat'])
print("dict_karyawan_7['tempat_tanggal_lahir']:",dict_karyawan_7['tempat_tanggal_lahir'])
print("dict_karyawan_7['jenis_kelamin']:",dict_karyawan_7['jenis_kelamin'])
print("dict_karyawan_7['agama']:",dict_karyawan_7['agama'])
print("dict_karyawan_7['hobi']:",dict_karyawan_7['hobi'])
print("dict_karyawan_7['umur']:",dict_karyawan_7['umur'])
print("dict_karyawan_7['asal_universitas']:",dict_karyawan_7['asal_universitas'])

dict_karyawan_8={'first_name': 'muhammad', 'last_name': 'dewa', 'NIK': '888', 'alamat': 'palagan km8', 'tempat_tanggal_lahir': 'palagan_8_8_8', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'voly', 'umur': '22', 'asal_universitas' : 'uny'}
print("dict_karyawan_8['first_name']:",dict_karyawan_8['first_name'])
print("dict_karyawan_8['last_name']:",dict_karyawan_8['last_name'])
print("dict_karyawan_8['NIK']:",dict_karyawan_8['NIK'])
print("dict_karyawan_8['alamat']:",dict_karyawan_8['alamat'])
print("dict_karyawan_8['tempat_tanggal_lahir']:",dict_karyawan_8['tempat_tanggal_lahir'])
print("dict_karyawan_8['jenis_kelamin']:",dict_karyawan_8['jenis_kelamin'])
print("dict_karyawan_8['agama']:",dict_karyawan_8['agama'])
print("dict_karyawan_8['hobi']:",dict_karyawan_8['hobi'])
print("dict_karyawan_8['umur']:",dict_karyawan_8['umur'])
print("dict_karyawan_8['asal_universitas']:",dict_karyawan_8['asal_universitas'])

dict_karyawan_9={'first_name': 'nur', 'last_name': 'rohmat', 'NIK': '999', 'alamat': 'palagan km9', 'tempat_tanggal_lahir': 'palagan_9_9_9', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'bulu_tangkis', 'umur': '22', 'asal_universitas' : 'ugm'}
print("dict_karyawan_9['first_name']:",dict_karyawan_9['first_name'])
print("dict_karyawan_9['last_name']:",dict_karyawan_9['last_name'])
print("dict_karyawan_9['NIK']:",dict_karyawan_9['NIK'])
print("dict_karyawan_9['alamat']:",dict_karyawan_9['alamat'])
print("dict_karyawan_9['tempat_tanggal_lahir']:",dict_karyawan_9['tempat_tanggal_lahir'])
print("dict_karyawan_9['jenis_kelamin']:",dict_karyawan_9['jenis_kelamin'])
print("dict_karyawan_9['agama']:",dict_karyawan_9['agama'])
print("dict_karyawan_9['hobi']:",dict_karyawan_9['hobi'])
print("dict_karyawan_9['umur']:",dict_karyawan_9['umur'])
print("dict_karyawan_9['asal_universitas']:",dict_karyawan_9['asal_universitas'])

dict_karyawan_10={'first_name': 'rifki', 'last_name': 'muhammad', 'NIK': '1010', 'alamat': 'palagan km10', 'tempat_tanggal_lahir': 'palagan_10_10_10', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'sepedaan', 'umur': '22', 'asal_universitas' : 'uty'}
print("dict_karyawan_10['first_name']:",dict_karyawan_10['first_name'])
print("dict_karyawan_10['last_name']:",dict_karyawan_10['last_name'])
print("dict_karyawan_10['NIK']:",dict_karyawan_10['NIK'])
print("dict_karyawan_10['alamat']:",dict_karyawan_10['alamat'])
print("dict_karyawan_10['tempat_tanggal_lahir']:",dict_karyawan_10['tempat_tanggal_lahir'])
print("dict_karyawan_10['jenis_kelamin']:",dict_karyawan_10['jenis_kelamin'])
print("dict_karyawan_10['agama']:",dict_karyawan_10['agama'])
print("dict_karyawan_10['hobi']:",dict_karyawan_10['hobi'])
print("dict_karyawan_10['umur']:",dict_karyawan_10['umur'])
print("dict_karyawan_10['asal_universitas']:",dict_karyawan_10['asal_universitas'])
# Out:
# dict_karyawan_1['first_name']: putri
# dict_karyawan_1['last_name']: ayu
# dict_karyawan_1['NIK']: 111
# dict_karyawan_1['alamat']: palagan km1
# dict_karyawan_1['tempat_tanggal_lahir']: palagan_1_1_1
# dict_karyawan_1['jenis_kelamin']: wanita
# dict_karyawan_1['agama']: islam
# dict_karyawan_1['hobi']: masak
# dict_karyawan_1['umur']: 22
# dict_karyawan_1['asal_universitas']: uty
# dict_karyawan_2['first_name']: bagus
# dict_karyawan_2['last_name']: nugraha
# dict_karyawan_2['NIK']: 222
# dict_karyawan_2['alamat']: palagan km2
# dict_karyawan_2['tempat_tanggal_lahir']: palagan_2_2_2
# dict_karyawan_2['jenis_kelamin']: pria
# dict_karyawan_2['agama']: islam
# dict_karyawan_2['hobi']: ngegame
# dict_karyawan_2['umur']: 22
# dict_karyawan_2['asal_universitas']: uny
# dict_karyawan_3['first_name']: bagas
# dict_karyawan_3['last_name']: cahyo
# dict_karyawan_3['NIK']: 333
# dict_karyawan_3['alamat']: palagan km3
# dict_karyawan_3['tempat_tanggal_lahir']: palagan_3_3_3
# ...

# %%
#dictionary karyawan
dict_karyawan_10={'first_name': 'rifki', 'last_name': 'muhammad', 'NIK': '1010', 'alamat': 'palagan km10', 'tempat_tanggal_lahir': 'palagan_10_10_10', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'sepedaan', 'umur': '22', 'asal_universitas' : 'uty'}
#mengubah entri yang sudah ada
dict_karyawan_10['umur']= 21
#menambah entri baru
dict_karyawan_10['hobi']= 'mancing'

print('umur:', dict_karyawan_10['umur'])
print('hobi:', dict_karyawan_10['hobi'])
# Out:
# umur: 21
# hobi: mancing

# %%
#menghapus dictionary karyawan
dict_karyawan_10={'first_name': 'rifki', 'last_name': 'muhammad', 'NIK': '1010', 'alamat': 'palagan km10', 'tempat_tanggal_lahir': 'palagan_10_10_10', 'jenis_kelamin': 'pria', 'agama': 'islam', 'hobi': 'sepedaan', 'umur': '22', 'asal_universitas' : 'uty'}
#hapus entri dengan key 'last_name'
del dict_karyawan_10['last_name']
dict_karyawan_10
#hapus semua entri di dict karyawan
#dict_karyawan_10.clear()
#hapus dictionary yang sudah ada
#del dict_karyawan_10
# Out:
# {'first_name': 'rifki',
#  'NIK': '1010',
#  'alamat': 'palagan km10',
#  'tempat_tanggal_lahir': 'palagan_10_10_10',
#  'jenis_kelamin': 'pria',
#  'agama': 'islam',
#  'hobi': 'sepedaan',
#  'umur': '22',
#  'asal_universitas': 'uty'}
